# %%
#!pip install spotipy
import spotipy  #Spotify web API wrapper for python
import spotipy.oauth2 as oauth2
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials 
import pandas as pd
import time  # Pause execution of loops

# %%
auth_manager = SpotifyClientCredentials(client_id='20b217018a7d490aad8006d599dec5f1', 
                                        client_secret='f4557422fbf0464fa6d08680100a7a30')

# %%
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
def get_trackFeatures(id):
    track_info = sp.track (id) 
    track_features = sp.audio_features (id)

#Track info
    name = track_info['name']
    album = track_info['album']['name']
    artist = track_info['album']['artists'][0]['name']
    release_date = track_info['album']['release_date']
    length = track_info['duration_ms']
    popularity = track_info['popularity']

#Track features
    acousticness = track_features[0]['acousticness']
    danceability = track_features[0]['danceability']
    energy = track_features[0]['energy']
    instrumentalness = track_features[0]['instrumentalness']
    liveness = track_features[0]['liveness']
    loudness = track_features[0]['loudness']
    speechiness = track_features[0]['speechiness']
    tempo = track_features[0]['tempo']
    time_signature = track_features[0]['time_signature']

    track = [name, album, artist, release_date, length, popularity, acousticness, danceability, energy, instrumentalness, 
             liveness, loudness, speechiness, tempo, time_signature]

    return track

# %%
def getTrackIDs(user, playlist_id):
    track_ids = []
    playlist = sp.user_playlist(user, playlist_id)
    for item in playlist['tracks']['items']:
        track = item['track']
        track_ids.append(track['id'])
    return track_ids

# %%
track_list = []

# %%
def playlistToDF(URI):
    for i in URI:
        track_ids = getTrackIDs('spotify',i)
        for j in track_ids:
            track_data = get_trackFeatures(j)
            track_list.append(track_data)

    playdf = pd.DataFrame(track_list,columns=['Name', 'Album', 'Artist', 'Release_date', 'Length', 'Popularity',
                                               'Acousticness', 'Danceability', 'Energy', 'Instrumentalness', 'Liveness',
                                               'Loudness', 'Speechiness', 'Tempo', 'Time Signature'])
    #playdf.to_csv("Data.csv",index = False, encoding='utf-8')
    return playdf

# %%
URI = []
URI.append('6bPfbndNnl9FIRoUVKgmF3') #Türkçe Rock En iyi 100
URI.append('37i9dQZF1DX5oKU1zTFGEH') #Türk Kahvesi
URI.append('37i9dQZF1DX9bvVeeesP1m') #Anadolu Rock
URI.append('37i9dQZF1DZ06evO1Sqlxq') #This Is Barış Manço
URI.append('37i9dQZF1DZ06evO0JTzoQ') #This Is Cem Karaca
URI.append('37i9dQZF1DWVHdYf9Bwcjq') #Hafif Müzik
URI.append('37i9dQZF1DXdXliePGSvEb') #Best Electronic Songs of 2022
URI.append('37i9dQZF1DWWSx7xoGkIMC') #Meyhane Şarkıları
URI.append('37i9dQZF1DXdnOj1VEuhgb') #NKVT

# %%
playdf = playlistToDF(URI)

# %%
URI = []
URI.append('37i9dQZF1DX8HtC0bZzINB') #Yaz Ritmi
URI.append('37i9dQZF1DZ06evO3zTpza') #This Is Sezen Aksu
URI.append('37i9dQZF1DWYteTcNVQZNq') #Türkçe 2000'ler
URI.append('37i9dQZF1DZ06evO2nMcpG') #This Is Yıldız Tilbe
URI.append('37i9dQZF1DXb7MJRXLczzR') #Türkçe 90'lar
URI.append('37i9dQZF1DZ06evO1pKjTT') #This Is Muazzez Ersoy
URI.append('37i9dQZF1DZ06evO2XMuRB') #This Is Orhan Gencebay

# %%
playdf = playlistToDF(URI)

# %%
URI = []
URI.append('37i9dQZF
Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# D:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# D:\Anaconda3\lib\http\client.py in getresponse(self)
#    1346             try:
# ...

# %%
URI = []
URI.append('37i9dQZF1DZ06evO2Rwuis') #This Is Simge
URI.append('37i9dQZF1DZ06evO3hP8GV') #This Is Ebru Gündeş
URI.append('37i9dQZF1DZ06evO08Xw9R') #This Is Mustafa Sandal
URI.append('37i9dQZF1DZ06evO00yqP5') #This Is Hande Yener
URI.append('37i9dQZF1DZ06evO0VwzCF') #This Is Gülşen

# %%
playdf = playlistToDF(URI)

# %%
URI = []
URI.append('37i9dQZF1DZ06evO0f9PCM') #This Is Hadise
URI.append('37i9dQZF1DZ06evO0SXlWG') #This Is Edis
URI.append('37i9dQZF1DX3FKrannpYzi') #Yılbaşı Özel
URI.append('37i9dQZF1DZ06evO1t4fWE') #This Is Tarkan

# %%
playdf = playlistToDF(URI)

# %%
URI = []
URI.append('37i9dQZF1DZ06evO2gcvK1') #This Is Yüksek Sadakat
URI.append('37i9dQZF1DX2iRL6tJD46O') #Duş Şarkıları
URI.append('37i9dQZF1DZ06evO22xi3C') #This Is Can Bonomo
URI.append('37i9dQZF1DWXoHqNlfcLJb') #OLAY
URI.append('37i9dQZF1DZ06evO2WpwQL') #This Is Yaşar
URI.append('37i9dQZF1DWYQalEXIZrSu') #Tbt
URI.append('37i9dQZF1DZ06evO2H8WJu') #This Is Pinhani
URI.append('37i9dQZF1DZ06evO37d71q') #This Is Mor ve Ötesi

# %%
playdf = playlistToDF(URI)

# %%
URI = []
URI.append('37i9dQZF1DX29brXfjEm5q') #This Is Sam Smith
URI.append('37i9dQZF1DX7KWRIlkUpsl') #This Is Maroon5
URI.append('37i9dQZF1DX5U6fr1hAMvg') #This Is Shawn Mendes
URI.append('37i9dQZF1DZ06evO0jO79m') #This Is Shakira
URI.append('37i9dQZF1DZ06evO3by276') #This Is Shakira
URI.append('37i9dQZF1DX5KpP2LN299J') #This Is Taylor Swift

# %%
playdf = playlistToDF(URI)

# %%
URI = []
URI.append('37i9dQZF1DZ06evO3Dik4U') #This Is Evgeny Grinko
URI.append('37i9dQZF1DZ06evO2vCLCL') #This Is Göksel
URI.append('37i9dQZF1DZ06evO3rgiop') #This Is Dedublüman
URI.append('37i9dQZF1DZ06evO0mG1Ne') #This Is LP
URI.append('37i9dQZF1DZ06evO1jG7Vv') #This Is MFÖ

# %%
playdf = playlistToDF(URI)

# %%
playdf
# Out:
#                        Name                 Album        Artist Release_date  \
# 0                     Belki                 Belki    Dedublüman   2022-08-05
# 1                  Bu Akşam   Belki Alışman Lazım         Duman   2002-10-16
# 2       Yıldızların Altında   Yıldızların Altında         Kargo   2005-07-14
# 3              Dibine Kadar               Duman 1         Duman   2010-07-06
# 4            Bir Derdim Var  Dünya Yalan Söylüyor  mor ve ötesi   2004-04-16
# ...                     ...                   ...           ...          ...
# 7942          Belalın Oldum               M.V.A.B           MFÖ   1995-05-30
# 7943  Bir Ordayım Bir Burda          Vak The Rock           MFÖ         1986
# 7944        Dönmem Yolumdan       Dönmem Yolumdan           MFÖ   1992-05-20
# 7945        Didai Didai Dai     Peki Peki Anladık           MFÖ   2007-02-14
# 7946           Yamuk Mu Var                Ve MFÖ           MFÖ   2011-08-11
#
# ...

# %%
playdf = playdf.drop_duplicates(subset="Name")

# %%
playdf
# Out:
#                        Name                 Album        Artist Release_date  \
# 0                     Belki                 Belki    Dedublüman   2022-08-05
# 1                  Bu Akşam   Belki Alışman Lazım         Duman   2002-10-16
# 2       Yıldızların Altında   Yıldızların Altında         Kargo   2005-07-14
# 3              Dibine Kadar               Duman 1         Duman   2010-07-06
# 4            Bir Derdim Var  Dünya Yalan Söylüyor  mor ve ötesi   2004-04-16
# ...                     ...                   ...           ...          ...
# 7942          Belalın Oldum               M.V.A.B           MFÖ   1995-05-30
# 7943  Bir Ordayım Bir Burda          Vak The Rock           MFÖ         1986
# 7944        Dönmem Yolumdan       Dönmem Yolumdan           MFÖ   1992-05-20
# 7945        Didai Didai Dai     Peki Peki Anladık           MFÖ   2007-02-14
# 7946           Yamuk Mu Var                Ve MFÖ           MFÖ   2011-08-11
#
# ...

# %%
playdf.reset_index(drop=True, inplace=True)

# %%
playdf
# Out:
#                        Name                 Album        Artist Release_date  \
# 0                     Belki                 Belki    Dedublüman   2022-08-05
# 1                  Bu Akşam   Belki Alışman Lazım         Duman   2002-10-16
# 2       Yıldızların Altında   Yıldızların Altında         Kargo   2005-07-14
# 3              Dibine Kadar               Duman 1         Duman   2010-07-06
# 4            Bir Derdim Var  Dünya Yalan Söylüyor  mor ve ötesi   2004-04-16
# ...                     ...                   ...           ...          ...
# 5031          Belalın Oldum               M.V.A.B           MFÖ   1995-05-30
# 5032  Bir Ordayım Bir Burda          Vak The Rock           MFÖ         1986
# 5033        Dönmem Yolumdan       Dönmem Yolumdan           MFÖ   1992-05-20
# 5034        Didai Didai Dai     Peki Peki Anladık           MFÖ   2007-02-14
# 5035           Yamuk Mu Var                Ve MFÖ           MFÖ   2011-08-11
#
# ...

# %%
playdf.to_csv("DataSet.csv",index = False, encoding='utf-8')

# %%
df = pd.read_csv('DataSet.csv')

# %%
df
# Out:
#                        Name                 Album        Artist Release_date  \
# 0                     Belki                 Belki    Dedublüman   2022-08-05
# 1                  Bu Akşam   Belki Alışman Lazım         Duman   2002-10-16
# 2       Yıldızların Altında   Yıldızların Altında         Kargo   2005-07-14
# 3              Dibine Kadar               Duman 1         Duman   2010-07-06
# 4            Bir Derdim Var  Dünya Yalan Söylüyor  mor ve ötesi   2004-04-16
# ...                     ...                   ...           ...          ...
# 5031          Belalın Oldum               M.V.A.B           MFÖ   1995-05-30
# 5032  Bir Ordayım Bir Burda          Vak The Rock           MFÖ         1986
# 5033        Dönmem Yolumdan       Dönmem Yolumdan           MFÖ   1992-05-20
# 5034        Didai Didai Dai     Peki Peki Anladık           MFÖ   2007-02-14
# 5035           Yamuk Mu Var                Ve MFÖ           MFÖ   2011-08-11
#
# ...
